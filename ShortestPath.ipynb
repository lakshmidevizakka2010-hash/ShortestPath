# %%
import heapq

# -------------------------------------------------
# SHORTEST PATH ROUTING SIMULATOR
# Dijkstra's Algorithm
# -------------------------------------------------

def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}

    distances[start] = 0

    priority_queue = [(0, start)]

    while priority_queue:
        current_distance, current_node = heapq.heappop(priority_queue)

        if current_distance > distances[current_node]:
            continue

        for neighbor, cost in graph[current_node]:
            distance = current_distance + cost

            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node

                heapq.heappush(
                    priority_queue,
                    (distance, neighbor)
                )

    return distances, previous


def get_path(previous, start, destination):
    path = []
    current = destination

    while current is not None:
        path.append(current)
        current = previous[current]

    path.reverse()

    if path[0] != start:
        return []

    return path


def display_routing_table(graph, start):
    distances, previous = dijkstra(graph, start)

    print("\n" + "=" * 65)
    print("              SHORTEST PATH ROUTING SIMULATOR")
    print("=" * 65)

    print(f"\nSource Router: {start}")

    print("\nRouting Table")
    print("-" * 65)

    print(f"{'Destination':<15}{'Cost':<15}{'Shortest Path'}")
    print("-" * 65)

    for destination in graph:
        if destination == start:
            path = [start]
        else:
            path = get_path(
                previous,
                start,
                destination
            )

        path_string = " -> ".join(path)

        if distances[destination] == float('inf'):
            print(
                f"{destination:<15}"
                f"{'INF':<15}"
                f"No Path"
            )
        else:
            print(
                f"{destination:<15}"
                f"{distances[destination]:<15}"
                f"{path_string}"
            )

    print("-" * 65)


def main():

    # Network topology
    graph = {
        'A': [('B', 4), ('C', 2)],
        'B': [('A', 4), ('C', 1), ('D', 5)],
        'C': [('A', 2), ('B', 1), ('D', 8), ('E', 10)],
        'D': [('B', 5), ('C', 8), ('E', 2), ('F', 6)],
        'E': [('C', 10), ('D', 2), ('F', 3)],
        'F': [('D', 6), ('E', 3)]
    }

    print("=" * 65)
    print("          COMPUTER NETWORK ROUTING SIMULATOR")
    print("=" * 65)

    print("\nAvailable Routers:")
    print(", ".join(graph.keys()))

    source = input("\nEnter source router: ").upper()

    if source not in graph:
        print("Invalid router!")
        return

    display_routing_table(graph, source)

    destination = input(
        "\nEnter destination router to find shortest path: "
    ).upper()

    if destination not in graph:
        print("Invalid destination router!")
        return

    distances, previous = dijkstra(graph, source)

    path = get_path(
        previous,
        source,
        destination
    )

    print("\n" + "=" * 65)
    print("                ROUTING RESULT")
    print("=" * 65)

    if not path:
        print(f"No route from {source} to {destination}.")
    else:
        print(f"Source      : {source}")
        print(f"Destination : {destination}")
        print(f"Shortest Path: {' -> '.join(path)}")
        print(f"Total Cost  : {distances[destination]}")

    print("=" * 65)


if __name__ == "__main__":
    main()
# Out:
# ...
#           COMPUTER NETWORK ROUTING SIMULATOR
# ...
#
# Available Routers:
# A, B, C, D, E, F
#
# Enter source router: A
#
# ...
#               SHORTEST PATH ROUTING SIMULATOR
# ...
#
# Source Router: A
#
# Routing Table
# -----------------------------------------------------------------
# Destination    Cost           Shortest Path
# -----------------------------------------------------------------
# A              0              A
# B              3              A -> C -> B
# C              2              A -> C
# D              8              A -> C -> B -> D
# E              10             A -> C -> B -> D -> E
# F              13             A -> C -> B -> D -> E -> F
# -----------------------------------------------------------------
#
# Enter destination router to find shortest path: E
#
# ...
#                 ROUTING RESULT
# ...
# Source      : A
# Destination : E
# Shortest Path: A -> C -> B -> D -> E
# Total Cost  : 10
# ...
